# %% [markdown]
# ## Denoising

# %% [markdown]
# Pour ce projet vous avez :
#
# Pour le train
# - Un dossier contenant des fichiers d'enregistrements de voix sans bruit (audio/voice_origin/train)
# - Un dossier contenant des fichiers d'enregistrements de voix avec une ambiance de rue en arrière-plan (audio/denoising/train)
# La correspondance entre un enregistrement avec ambiance et l'enregistrement parfait de la voix se fait via le nom des fichiers.
#
# Pour l'ensemble de test vous avez deux ensembles de fichiers similaires.
#
# Dans audio/voice_origin et audio/denoising vous avec un dossier train_small de petite taille que vous pouvez télécharger rapidement pour faire des essai.
#
# L'objectif est d'estimer à partir du signal bruité le signal de voix.
#
# Les signaux ont un SNR (Signal to Noise Ratio) compris entre 0 et 20 dB.
#
# Vous pouvez au choix travailler
# - sur le spectrogramme par exemple en vous des approches par masquage présentés dans le cours 09 et en estimant les masques avec un réseau Seq2Seq de votre choix ou un UNet (cf A. Jansson et Al., SINGING VOICE SEPARATION WITH DEEP U-NET CONVOLUTIONAL NETWORK, ISMIR 2017 )
# - directement sur la forme d'onde  :
#    - cf D. Stoller  et Al., WAVE-U-NET: A MULTI-SCALE NEURAL NETWORK FOR END-TO-END AUDIO SOURCE SEPARATION, ISMIR 2018
#    - les apporches TAS NEt : Y. Luo et Al., TaSNet: Time-Domain Audio Separation Network for Real-Time, Single-Channel Speech Separation, ICASSP 2018 ou Y. Luo et Al.,  Conv-tasnet: surpassing ideal time–frequency magnitude masking for speech separation. IEEE/ACM Transactions on Audio, Speech, and Language Processing, 2019.
#
#
# Libre à vous de choisir la fonction de perte utilisée dans l’entraînement et adaptée au format des données que vous utiliserez en entrée du réseau de neurones.
#
# Pour l'évaluation des performances sur l'ensemble de test, outre la fonction de perte vous vous intéresserez au PESQ et au STOI des voix estimées.

# %%
path = "drive/MyDrive/MVA/DeepSignal/"

# %%
# !pip install pySTOI
# !pip install pesq

# %%
import os
import sys
import numpy as np
import scipy.io.wavfile as wavfile
import matplotlib.pyplot as plt
import scipy
import IPython.display as ipd
import torchaudio
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
from scipy.io import wavfile
from scipy.io import wavfile
from pystoi import stoi
from pesq import pesq
import soundfile as sf

# %%
# !mkdir denoising
# !unzip drive/MyDrive/MVA/DeepSignal/denoising/test.zip -d denoising
# !unzip drive/MyDrive/MVA/DeepSignal/denoising/train.zip -d denoising
# !mkdir voice_origin
# !unzip drive/MyDrive/MVA/DeepSignal/voice_origin/test.zip -d voice_origin
# !unzip drive/MyDrive/MVA/DeepSignal/voice_origin/train.zip -d voice_origin

# %% [markdown]
# ## Visualisation

# %%
# Import audio .wav file with scipy.io.wavfile.read

rate, data = scipy.io.wavfile.read('denoising/train/Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap01_0_.wav')


# Listen to the audio file with IPython.display.Audio

ipd.Audio(data, rate=rate)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# ## Data

# %%
def normalize_waveform(waveform):
    # Normalize the waveform in the range [-1, 1]
    return waveform / np.max(np.abs(waveform))

class AudioDenoisingDataset(Dataset):
    def __init__(self, noisy_dir, clean_dir):
        self.noisy_files = [os.path.join(noisy_dir, f) for f in os.listdir(noisy_dir) if f.endswith('.wav')]
        self.clean_files = [os.path.join(clean_dir, f) for f in os.listdir(clean_dir) if f.endswith('.wav')]
        assert len(self.noisy_files) == len(self.clean_files), "Mismatch in dataset size"

    def __len__(self):
        return len(self.noisy_files)

    def __getitem__(self, idx):
        # Use scipy.io.wavfile.read to read the wav file
        noisy_rate, noisy_waveform = wavfile.read(self.noisy_files[idx])
        clean_rate, clean_waveform = wavfile.read(self.clean_files[idx])

        # convert clean_rate which is in int16 to float32
        clean_waveform = clean_waveform.astype(np.float32)
        noisy_waveform = noisy_waveform.astype(np.float32)

        # Apply normalization directly here
        noisy_waveform = normalize_waveform(noisy_waveform)
        clean_waveform = normalize_waveform(clean_waveform)

        return noisy_waveform, clean_waveform

# %%
train_dataset = AudioDenoisingDataset('denoising/train/', 'voice_origin/train/')
test_dataset = AudioDenoisingDataset('denoising/test/', 'voice_origin/test/')

# %%
train_loader = DataLoader(train_dataset, batch_size=48, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=48, shuffle=False)

# %%
# Iterate over the DataLoader
for i, (inputs, labels) in enumerate(train_loader):
    print(f"Batch {i}:")
    print("  Input shape:", inputs.shape)
    print("  Label shape:", labels.shape)
    # Plot the first input and label in the batch
    plt.figure()
    plt.subplot(211)
    plt.title("Input")
    plt.plot(inputs[0, :])
    plt.subplot(212)
    plt.title("Label")
    plt.plot(labels[0, :])
    plt.show()
    if i == 0:  # Just to check the first batch as an example
        break
# Out:
# Batch 0:
#   Input shape: torch.Size([48, 80000])
#   Label shape: torch.Size([48, 80000])

# %% [markdown]
# ## Model

# %%
import torch
import torch.nn as nn


class TasNet(nn.Module):
    def __init__(self, in_channels, out_channels):
        self.conv = nn.Conv1d(in_channels, out_channels, kernel_size, stride, padding)
        self.relu = nn.ReLU()

# %%
import torch
import torch.nn as nn

class DownsamplingBlock(nn.Module):
    def __init__(self, in_channels, out_channels, kernel_size=15, stride=1, padding=7, pool_size=2):
        super(DownsamplingBlock, self).__init__()
        self.conv = nn.Conv1d(in_channels, out_channels, kernel_size, stride, padding)
        self.batchnorm = nn.BatchNorm1d(out_channels)  # Adding a batch normalization layer
        self.relu = nn.LeakyReLU(0.2)
        self.pool = nn.AvgPool1d(pool_size)

    def forward(self, x):
        x = self.conv(x)
        x = self.batchnorm(x)  # Apply batch normalization after convolution
        skip = self.relu(x)
        # x = self.pool(skip)
        x = skip[:, :, ::2]
        return x, skip

class WaveUNetDownsampling(nn.Module):
    def __init__(self, channel_sizes=[1, 24, 48, 72, 96, 120, 144, 168, 192, 216, 240, 264, 288]):
        super(WaveUNetDownsampling, self).__init__()
        self.downsampling_blocks = nn.ModuleList()
        for i in range(len(channel_sizes) - 1):
            block = DownsamplingBlock(channel_sizes[i], channel_sizes[i+1])
            self.downsampling_blocks.append(block)

    def forward(self, x):
        skip_connections = [x]
        for block in self.downsampling_blocks:
            x, skip = block(x)
            skip_connections.append(skip)
        return x, skip_connections[::-1]

# %%
class UpsamplingBlock(nn.Module):
    def __init__(self, in_channels, out_channels, kernel_size=5, stride=1, padding=2):
        super(UpsamplingBlock, self).__init__()
        self.upsample = nn.Upsample(scale_factor=2, mode='linear', align_corners=True)
        self.conv = nn.Conv1d(in_channels, out_channels, kernel_size, stride, padding)
        self.batchnorm = nn.BatchNorm1d(out_channels)  # Adding a batch normalization layer
        self.relu = nn.LeakyReLU(0.2)


    def forward(self, x, skip_connection):
        x = self.upsample(x)
        x = torch.cat((x, skip_connection), 1)
        x = self.conv(x)
        x = self.batchnorm(x)  # Apply batch normalization after convolution
        self.relu = nn.LeakyReLU(0.2)
        return x

class WaveUNetUpsampling(nn.Module):
    def __init__(self, channel_sizes=[312, 288, 264, 240, 216, 192, 168, 144, 120, 96, 72, 48, 24]):
        super(WaveUNetUpsampling, self).__init__()
        self.upsampling_blocks = nn.ModuleList()
        for i in range(len(channel_sizes)-1):
            in_channels = channel_sizes[i+1] + channel_sizes[i]
            out_channels = channel_sizes[i+1]
            block = UpsamplingBlock(in_channels, out_channels)
            self.upsampling_blocks.append(block)

    def forward(self, x, skip_connections):
        for i, block in enumerate(self.upsampling_blocks):
            x = block(x, skip_connections[i])
        return x

class WaveUNet(nn.Module):
    def __init__(self):
        super(WaveUNet, self).__init__()
        self.downsampling = WaveUNetDownsampling()
        self.bottleneck = nn.Conv1d(288, 312, kernel_size=15, padding=7)
        self.upsampling = WaveUNetUpsampling()
        self.final_conv = nn.Conv1d(in_channels=25, out_channels=1, kernel_size=1)
        self.tanh = nn.Tanh()

    def forward(self, x ):
        desired_length = 2**16  # 65,536
        x = x[:, :, :desired_length]
        x, skip_connections = self.downsampling(x)
        x = self.bottleneck(x)
        x = self.upsampling(x, skip_connections)
        x = self.final_conv(torch.cat((x, skip_connections[-1]), 1))
        x = self.tanh(x)
        return x

# %%
# Check if CUDA is available and move the model to GPU if possible
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader
import time
model = WaveUNet().to(device)

criterion = nn.MSELoss()

# Select an optimizer
optimizer = optim.Adam(model.parameters(), lr=0.001)

train_loader = DataLoader(train_dataset, batch_size=16 , shuffle=True)
val_loader = DataLoader(test_dataset, batch_size=16, shuffle=False)

# %%
import time
import torch

epochs = 60  # Number of epochs
best_val_loss = float('inf')  # Initialize the best validation loss as infinity
start_time = time.time()

for epoch in range(epochs):
    model.train()  # Set the model to training mode
    total_loss = 0

    for batch in train_loader:
        inputs, targets = batch

        inputs = inputs.unsqueeze(1).to(device)
        targets = targets.unsqueeze(1).to(device)

        # Zero the parameter gradients
        optimizer.zero_grad()

        # Forward pass
        outputs = model(inputs)
        desired_length = 2**16  # 65,536
        # desired_length = 2**14  # 16384

        targets = targets[:, :, :desired_length]
        loss = criterion(outputs, targets)

        # Backward pass and optimize
        loss.backward()
        optimizer.step()

        total_loss += loss.item()

    train_loss = total_loss / len(train_loader)

    model.eval()  # Set the model to evaluation mode
    total_loss = 0

    with torch.no_grad():  # No need to track the gradients
        for batch in val_loader:
            inputs, targets = batch

            inputs = inputs.unsqueeze(1).to(device)
            targets = targets.unsqueeze(1).to(device)

            # Forward pass
            outputs = model(inputs)
            targets = targets[:, :, :desired_length]
            loss = criterion(outputs, targets)

            total_loss += loss.item()

    val_loss = total_loss / len(val_loader)

    print(f"Epoch {epoch+1}/{epochs} - time: {time.time()-start_time:.2f} - Training Loss: {train_loss:.8f}, Validation Loss: {val_loss:.8f}")

    # Save the model if the validation loss improved
    if val_loss < best_val_loss:
        best_val_loss = val_loss
        torch.save(model.state_dict(), 'denoise_waveunet.pt')
        print(f"Model saved at epoch {epoch+1} with validation loss: {best_val_loss:.8f}")
# Out:
# Epoch 1/60 - time: 25.93 - Training Loss: 0.00514839, Validation Loss: 0.00110294
# Model saved at epoch 1 with validation loss: 0.00110294
# Epoch 2/60 - time: 52.40 - Training Loss: 0.00105315, Validation Loss: 0.00091678
# Model saved at epoch 2 with validation loss: 0.00091678
# Epoch 3/60 - time: 78.26 - Training Loss: 0.00095716, Validation Loss: 0.00088110
# Model saved at epoch 3 with validation loss: 0.00088110
# Epoch 4/60 - time: 104.19 - Training Loss: 0.00091520, Validation Loss: 0.00080015
# Model saved at epoch 4 with validation loss: 0.00080015
# Epoch 5/60 - time: 130.15 - Training Loss: 0.00087865, Validation Loss: 0.00077968
# Model saved at epoch 5 with validation loss: 0.00077968
# Epoch 6/60 - time: 156.15 - Training Loss: 0.00086669, Validation Loss: 0.00078911
# Epoch 7/60 - time: 182.03 - Training Loss: 0.00083722, Validation Loss: 0.00084024
# Epoch 8/60 - time: 207.97 - Training Loss: 0.00081167, Validation Loss: 0.00077649
# Model saved at epoch 8 with validation loss: 0.00077649
# Epoch 9/60 - time: 233.94 - Training Loss: 0.00085419, Validation Loss: 0.00080854
# Epoch 10/60 - time: 259.93 - Training Loss: 0.00080215, Validation Loss: 0.00075487
# Model saved at epoch 10 with validation loss: 0.00075487
# Epoch 11/60 - time: 286.02 - Training Loss: 0.00075927, Validation Loss: 0.00073861
# Model saved at epoch 11 with validation loss: 0.00073861
# Epoch 12/60 - time: 311.96 - Training Loss: 0.00074804, Validation Loss: 0.00086304
# Epoch 13/60 - time: 337.81 - Training Loss: 0.00075386, Validation Loss: 0.00069968
# Model saved at epoch 13 with validation loss: 0.00069968
# Epoch 14/60 - time: 363.79 - Training Loss: 0.00072253, Validation Loss: 0.00087596
# Epoch 15/60 - time: 389.62 - Training Loss: 0.00072272, Validation Loss: 0.00074892
# Epoch 16/60 - time: 415.46 - Training Loss: 0.00073402, Validation Loss: 0.00068882
# Model saved at epoch 16 with validation loss: 0.00068882
# Epoch 17/60 - time: 441.40 - Training Loss: 0.00069928, Validation Loss: 0.00081014
# Epoch 18/60 - time: 467.42 - Training Loss: 0.00070444, Validation Loss: 0.00068650
# Model saved at epoch 18 with validation loss: 0.00068650
# Epoch 19/60 - time: 493.33 - Training Loss: 0.00068432, Validation Loss: 0.00072264
# Epoch 20/60 - time: 519.12 - Training Loss: 0.00069774, Validation Loss: 0.00063563
# Model saved at epoch 20 with validation loss: 0.00063563
# Epoch 21/60 - time: 545.01 - Training Loss: 0.00067912, Validation Loss: 0.00064325
# Epoch 22/60 - time: 570.81 - Training Loss: 0.00067397, Validation Loss: 0.00067053
# Epoch 23/60 - time: 596.67 - Training Loss: 0.00066604, Validation Loss: 0.00066147
# Epoch 24/60 - time: 622.51 - Training Loss: 0.00065372, Validation Loss: 0.00060714
# Model saved at epoch 24 with validation loss: 0.00060714
# Epoch 25/60 - time: 648.42 - Training Loss: 0.00063498, Validation Loss: 0.00063922
# Epoch 26/60 - time: 674.32 - Training Loss: 0.00068338, Validation Loss: 0.00062414
# Epoch 27/60 - time: 700.33 - Training Loss: 0.00067234, Validation Loss: 0.00064746
# Epoch 28/60 - time: 726.15 - Training Loss: 0.00063163, Validation Loss: 0.00062250
# Epoch 29/60 - time: 751.99 - Training Loss: 0.00065173, Validation Loss: 0.00067765
# Epoch 30/60 - time: 777.83 - Training Loss: 0.00063704, Validation Loss: 0.00059540
# Model saved at epoch 30 with validation loss: 0.00059540
# Epoch 31/60 - time: 803.75 - Training Loss: 0.00061914, Validation Loss: 0.00060727
# Epoch 32/60 - time: 829.58 - Training Loss: 0.00063272, Validation Loss: 0.00072696
# Epoch 33/60 - time: 855.49 - Training Loss: 0.00061997, Validation Loss: 0.00059507
# Model saved at epoch 33 with validation loss: 0.00059507
# Epoch 34/60 - time: 881.43 - Training Loss: 0.00061595, Validation Loss: 0.00059255
# Model saved at epoch 34 with validation loss: 0.00059255
# Epoch 35/60 - time: 907.44 - Training Loss: 0.00061075, Validation Loss: 0.00057980
# Model saved at epoch 35 with validation loss: 0.00057980
# Epoch 36/60 - time: 933.43 - Training Loss: 0.00059983, Validation Loss: 0.00061614
# Epoch 37/60 - time: 959.26 - Training Loss: 0.00058740, Validation Loss: 0.00058138
# Epoch 38/60 - time: 985.09 - Training Loss: 0.00058436, Validation Loss: 0.00056439
# Model saved at epoch 38 with validation loss: 0.00056439
# Epoch 39/60 - time: 1011.03 - Training Loss: 0.00058855, Validation Loss: 0.00056861
# Epoch 40/60 - time: 1036.95 - Training Loss: 0.00058709, Validation Loss: 0.00054983
# Model saved at epoch 40 with validation loss: 0.00054983
# Epoch 41/60 - time: 1062.88 - Training Loss: 0.00058149, Validation Loss: 0.00056325
# Epoch 42/60 - time: 1088.68 - Training Loss: 0.00059371, Validation Loss: 0.00054017
# Model saved at epoch 42 with validation loss: 0.00054017
# Epoch 43/60 - time: 1114.74 - Training Loss: 0.00057006, Validation Loss: 0.00057414
# Epoch 44/60 - time: 1140.52 - Training Loss: 0.00057577, Validation Loss: 0.00058020
# Epoch 45/60 - time: 1166.36 - Training Loss: 0.00057828, Validation Loss: 0.00053892
# Model saved at epoch 45 with validation loss: 0.00053892
# Epoch 46/60 - time: 1192.31 - Training Loss: 0.00058197, Validation Loss: 0.00054957
# Epoch 47/60 - time: 1218.28 - Training Loss: 0.00057821, Validation Loss: 0.00058745
# Epoch 48/60 - time: 1244.15 - Training Loss: 0.00057172, Validation Loss: 0.00054059
# Epoch 49/60 - time: 1269.98 - Training Loss: 0.00056588, Validation Loss: 0.00055392
# Epoch 50/60 - time: 1295.81 - Training Loss: 0.00054553, Validation Loss: 0.00053108
# Model saved at epoch 50 with validation loss: 0.00053108
# Epoch 51/60 - time: 1321.85 - Training Loss: 0.00055009, Validation Loss: 0.00054492
# Epoch 52/60 - time: 1347.66 - Training Loss: 0.00053610, Validation Loss: 0.00052855
# Model saved at epoch 52 with validation loss: 0.00052855
# Epoch 53/60 - time: 1373.64 - Training Loss: 0.00054689, Validation Loss: 0.00054304
# Epoch 54/60 - time: 1399.55 - Training Loss: 0.00054635, Validation Loss: 0.00052016
# Model saved at epoch 54 with validation loss: 0.00052016
# Epoch 55/60 - time: 1425.47 - Training Loss: 0.00054338, Validation Loss: 0.00051827
# Model saved at epoch 55 with validation loss: 0.00051827
# Epoch 56/60 - time: 1451.41 - Training Loss: 0.00053598, Validation Loss: 0.00051459
# Model saved at epoch 56 with validation loss: 0.00051459
# Epoch 57/60 - time: 1477.40 - Training Loss: 0.00053845, Validation Loss: 0.00051635
# Epoch 58/60 - time: 1503.28 - Training Loss: 0.00052692, Validation Loss: 0.00052342
# Epoch 59/60 - time: 1529.19 - Training Loss: 0.00053240, Validation Loss: 0.00051411
# Model saved at epoch 59 with validation loss: 0.00051411
# Epoch 60/60 - time: 1555.21 - Training Loss: 0.00053266, Validation Loss: 0.00051628

# %%
# Load the trained model
model = WaveUNet()
model.load_state_dict(torch.load('denoise_waveunet.pt'))
model.eval()

example_file = "Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap03_100_.wav"
rate, input = scipy.io.wavfile.read('/content/denoising/test/'+example_file)

rate, target = scipy.io.wavfile.read('/content/voice_origin/test/'+example_file)


input = torch.from_numpy(input)
input = input.unsqueeze(0)
input = input.unsqueeze(0)

prediction = model(input)
prediction = prediction.squeeze(0).squeeze(0)

# num_chunks = 4
# chunk_size = 2**14
# combined_prediction = []
# for j in range(num_chunks):
#     # Extracting the chunk from input and target
#     start_idx = j * chunk_size
#     end_idx = start_idx + chunk_size
#     input_chunk = input[:, :, start_idx:end_idx]
#     target_chunk = target[start_idx:end_idx]

#     with torch.no_grad():
#         # Get model prediction for the chunk
#         prediction_chunk = model(input_chunk)
#         combined_prediction.append(prediction_chunk.squeeze(0).squeeze(0).cpu().numpy())

# # Concatenating the predictions
# combined_prediction = np.concatenate(combined_prediction)

# %%
plt.figure()
plt.subplot(311)
plt.title("Input")
plt.plot(input.squeeze(0).squeeze(0).cpu())
plt.xlim(0, 80000)
plt.subplot(312)
plt.title("Prediction")
plt.plot(prediction.detach().numpy())
plt.xlim(0, 80000)
plt.subplot(313)
plt.title("Target")
plt.plot(target)
plt.xlim(0, 80000)
plt.show()

# %%
# Listen to the input, prediction and target
ipd.Audio(input.squeeze(0).squeeze(0).numpy(), rate=rate)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
ipd.Audio(prediction.detach().numpy(), rate=rate)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
audio_data = prediction.detach().numpy()
wavfile.write('output_audio.wav', rate, audio_data)

# %%
ipd.Audio(target, rate=rate)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# model = WaveUNet().to(device)
# model.load_state_dict(torch.load('denoise_waveunet.pt'))
# model.eval()
model = model.to(device)

# %%
stoi_originals, stoi_preds, pesq_originals, pesq_preds = [], [], [], []
chunk_size = 2**14  # 16,384
num_chunks = 80000 // chunk_size  # Assuming input length is 80000

for i, (input, target) in enumerate(test_dataset):
    input = torch.from_numpy(input).unsqueeze(0).unsqueeze(0).to(device)
    target = target[:65536]  # Assuming target is same length as input

    combined_prediction = []
    for j in range(num_chunks):
        # Extracting the chunk from input and target
        start_idx = j * chunk_size
        end_idx = start_idx + chunk_size
        input_chunk = input[:, :, start_idx:end_idx]
        target_chunk = target[start_idx:end_idx]

        with torch.no_grad():
            # Get model prediction for the chunk
            prediction_chunk = model(input_chunk)
            combined_prediction.append(prediction_chunk.squeeze(0).squeeze(0).cpu().numpy())

    # Concatenating the predictions
    combined_prediction = np.concatenate(combined_prediction)

    # STOI and PESQ evaluations
    stoi_original = stoi(target, input.squeeze(0).squeeze(0).cpu().numpy()[:65536], rate)
    stoi_pred = stoi(target, combined_prediction, rate)
    pesq_original = pesq(rate, target, input.squeeze(0).squeeze(0).cpu().numpy()[:65536], 'nb')
    pesq_pred = pesq(rate, target, combined_prediction, 'nb')

    stoi_originals.append(stoi_original)
    stoi_preds.append(stoi_pred)
    pesq_originals.append(pesq_original)
    pesq_preds.append(pesq_pred)

stoi_diffs = [a - b for a, b in zip(stoi_preds, stoi_originals)]  # >0 is better
pesq_diffs = [a - b for a, b in zip(pesq_preds, pesq_originals)]  # >0 is better

# %%
stoi_originals,stoi_preds, pesq_originals, pesq_preds = [], [], [], []
stop = 200
for i, (input, target) in enumerate(test_dataset):
    # if i==stop:
    #     break
    input = torch.from_numpy(input).unsqueeze(0).unsqueeze(0).to(device)
    with torch.no_grad():
        prediction = model(input)
        #desired_length = 2**16  # 65,536
        desired_length = 2**16  # 16384

        target = target[:desired_length]
        input = input[:,:,:desired_length]

        stoi_originals.append(stoi(target, input.squeeze(0).squeeze(0).cpu().numpy(), rate))
        stoi_preds.append(stoi(target, prediction.squeeze(0).squeeze(0).cpu().numpy(), rate))
        pesq_originals.append(pesq(rate, target, input.squeeze(0).squeeze(0).cpu().numpy(), 'nb'))
        pesq_preds.append(pesq(rate, target, prediction.squeeze(0).squeeze(0).cpu().numpy(), 'nb'))
stoi_diffs = [a - b for a, b in zip(stoi_preds, stoi_originals)]  # >0 is better
pesq_diffs = [a - b for a, b in zip(pesq_preds, pesq_originals)]  # >0 is better

# %%
plt.hist2d(stoi_diffs, pesq_diffs, bins=(70, 70), cmap='viridis')

# Add colorbar
plt.colorbar()
# plt.xlim(-0.04, 0.05)  # Set the x-axis limits
# plt.ylim(-0.1, 0.7)  # Set the y-axis limits
# Set labels and title
plt.xlabel('STOI Differences')
plt.ylabel('PESQ Differences')
plt.axhline(0, color='red', linestyle=':', linewidth=1)
plt.axvline(0, color='red', linestyle=':', linewidth=1)
plt.scatter(np.mean(stoi_diffs), np.mean(pesq_diffs), c='red', marker='x', label='Barycenter', s=80)
print("Mean STOI : ",np.mean(stoi_diffs))
print("Mean PESQ : ",np.mean(pesq_diffs))
plt.legend()
# Show the plot
plt.show()
# Out:
# Mean STOI :  0.0025474397917845514
# Mean PESQ :  0.24571547925929585
